# %% [markdown]
# <h3 align='center'>Трикутник Паскаля 1 🌶️</h3>
# Трикутник Паскаля - нескінченна таблиця біноміальних коефіцієнтів, що має трикутну форму. У цьому трикутнику на вершині та з боків стоять одиниці. Кожне число дорівнює сумі двох розташованих над ним чисел.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-10%20%D0%B2%2016.11.21.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-10%20%D0%B2%2016.11.21.png)

# %% [markdown]
# На вхід до програми подається число nn. Напишіть програму, яка повертає вказаний рядок трикутника Паскаля у вигляді списку (нумерація рядків починається з нуля).
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подається число n (n≥0).
#
# <b>Формат вихідних даних</b><br>
# Програма має вивести вказаний рядок трикутника Паскаля у вигляді списку.
#
# <b>Примітка 1</b>. Рішення зручно оформити у вигляді функції pascal(), яка приймає номер рядка та повертає відповідний рядок трикутника Паскаля.
#
# <b>Примітка 2</b>. Графічна ілюстрація формування трикутника Паскаля.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-10%20%D0%B2%2016.11.27.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-01-10%20%D0%B2%2016.11.27.png)

# %%
from math import factorial

n = (int(input())+1)

my_list = [0] * (n)
    
for i in range(n):
    for j in range(i+1):
        if i == (n-1):
            my_list[j] = (factorial(i)//(factorial(j)*factorial(i-j)))
            
print(my_list)
# Out:
# 4
# [1, 4, 6, 4, 1]

# %% [markdown]
# <h3 align='center'>Трикутник Паскаля 2</h3>
# На вхід до програми подається натуральне число n. Напишіть програму, яка виводить перші n рядків трикутника Паскаля.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подається число n (n≥1).
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести перші nn рядків трикутника Паскаля, кожен на окремому рядку відповідно до зразка.

# %%
from math import factorial 

n = int(input())
for i in range(n):
    for j in range(i+1):
        print(factorial(i)//(factorial(j)*factorial(i-j)), end=" ")
    print()
# Out:
# 4
# 1
# 1 1
# 1 2 1
# 1 3 3 1

# %% [markdown]
# <h3 align='center'>Упаковка дублікатів 🌶️</h3>
# На вхід до програми подається рядок тексту, що містить символи. Напишіть програму, яка пакує послідовності однакових символів заданого рядка в підсписки.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подається рядок тексту, що містить символи, відокремлені символом пропуску.
#
# <b>Формат вихідних даних</b><br>
# Програма має вивести вказаний список.

# %%
# put your python code here
text = input().split(' ')
lst = [['']]
for i, item in enumerate(text):
    if lst[-1][0] == item:
        lst[-1].append(item)
    else:
        lst.append([item])
lst.remove([''])
print(lst)
# Out:
# w w w o r l d g g g g r e a t t e c c h e m g g p w w
# [['w', 'w', 'w'], ['o'], ['r'], ['l'], ['d'], ['g', 'g', 'g', 'g'], ['r'], ['e'], ['a'], ['t', 't'], ['e'], ['c', 'c'], ['h'], ['e'], ['m'], ['g', 'g'], ['p'], ['w', 'w']]

# %% [markdown]
# <h3 align='center'>Розбиття на чанки 🌶️</h3>
# На вхід програмі подаються два рядки, однією символи, в інший число nn. З першого рядка формується перелік.
#
# Реалізуйте функцію chunked(), яка приймає на вхід список та число, що задає розмір чанка (шматка), а повертає список із чанків вказаної довжини.
#
# <b>Формат вхідних даних</b><br>
# На вхід програмі подається рядок тексту, що містить символи, відокремлені символом пропуску та число nn на окремому рядку.
#
# <b>Формат вихідних даних</b><br>
# Програма має вивести вказаний список.
#
# <b>Примітка</b>. Не забудьте викликати функцію chunked(), щоб вивести результат 😀.

# %%
# put your python code here
text = input().split(' ')
n = int(input())
lst = []
temp = []
 
for k, item in enumerate(text):
    temp.append(item)
    if len(temp) == n:
        lst.append(temp)
        temp = []
if (len(temp) % n) != 0:
    lst.append(temp)
print(lst)
# Out:
# a b c d e
# 2
# [['a', 'b'], ['c', 'd'], ['e']]

# %% [markdown]
# <h3 align='center'>Підписки списку 🌶️🌶️</h3>
# Підсписок — це частина іншого списку. Підсписок може містити один елемент, кілька і навіть жодного. Наприклад, [1], [2], [3] та [4] - підписки списку [1, 2, 3, 4]. Список [2, 3] — підсписок списку [1, 2, 3, 4], але список [2, 4] не підсписок списку [1, 2, 3, 4], оскільки елементи 22 та 44 у другому списку не суміжні . Порожній список – підсписок будь-якого списку. Сам список - підсписок себе, тобто список [1, 2, 3, 4] підсписок списку [1, 2, 3, 4].
#
# На вхід до програми подається рядок тексту, що містить символи. З цього рядка формується список. Напишіть програму, яка виводить список, що містить усі можливі підписки списку, включаючи пустий список.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подається рядок тексту, що містить символи, відокремлені символом пропуску.
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести вказаний список, що містить усі можливі підписки, включаючи порожній список відповідно до прикладів.
#
# <b>Примітка</b>. Порядок списків однакової довжини має відповідати порядку їхнього входження до основного списку.

# %%
# put your python code here
text = input().split(' ')
lst = []
result = [[]]
for i in range(len(text)):
    for j in range(len(text)):
        lst = text[j:i + j + 1]
        if len(lst) == i + 1:
            result.append(lst)
print(result)
# Out:
# 1 2 3
# [[], ['1'], ['2'], ['3'], ['1', '2'], ['2', '3'], ['1', '2', '3']]
