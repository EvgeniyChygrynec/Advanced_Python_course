# %% [markdown]
# <h3 align='center'>Домашнє завдання</h3>
# Вчитель перевіряє домашнє завдання у класі і отримав такі відповіді: з n школярів у m домашнє завдання з'їв собака, у k відключили світло, а p учнів спіткали обидва нещастя. Напишіть програму, яка визначає, скільки людей виконало домашнє завдання.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подаються числа n, m, k, p кожне на окремому рядку.
#
# <b>Формат вихідних даних</b><br>
# Програма має вивести кількість учнів, які зробили домашнє завдання.

# %%
# put your python code here
n, m, k, p = [int(input()) for i in range(4)]
print('')
print(n-(m-p+p+k-p))
# Out:
# 35
# 20
# 10
# 3
#
# 8

# %% [markdown]
# <h3 align='center'>Схід</h3>
# На супутнику «Схід» встановлено прилад для вимірювання сонячної активності. Щохвилини він передає в обсерваторію каналом зв'язку позитивне ціле число — кількість енергії сонячного випромінювання. Для правильного аналізу результатів немає необхідності тримати дані, що повторюються. Напишіть програму, яка виводить максимальну кількість свідчень супутника, при видаленні яких результат буде правильно проаналізовано.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подається один рядок, що містить числа – показання супутника «Схід». Числа вказуються через пропуск і містять провідних нулів.
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести максимальну кількість показань, після видалення яких аналіз результатів буде зроблено правильно.

# %%
# put your python code here
n = input().split(' ')
print('')
print(len(n)-len(set(n)))
# Out:
# 10 20 30 40 10 50
#
# 1

# %% [markdown]
# <h3 align='center'>Міста</h3>
# Тимур та Руслан грають у гру міста. Вони дуже люблять цю гру і знають багато міст, особливо Тимур, однак до кінця гри через свій вік забувають, які міста вже називали.
#
# Напишіть програму, яка зчитує інформацію про гру та повідомляє хлопцям, що чергове місто названо повторно.
#
# <b>Формат вхідних даних</b><br>
# На вхід програмі в першому рядку подається натуральне число nn – кількість названих міст, у наступних nn рядках вводяться названі міста та ще один рядок з новим, щойно названим містом.
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести OK, якщо це місто ще не згадували, та REPEAT, якщо місто вже було названо.

# %%
# put your python code here
n = int(input())
lst = []
for _ in range(n+1):
    lst.append(input())
flag = len(lst)-len(set(lst))
print('')
if flag == 0: print('OK')
else: print('REPEAT')
# Out:
# 5
# Лас-Вегас
# Сеул
# Лондон
# Ницца
# Адел
# Лас-Вегас
#
# REPEAT

# %% [markdown]
# <h3 align='center'>Книги на прочитання</h3>
# Руслан отримав наприкінці навчального року список літератури на літо. Тепер йому треба з'ясувати, які книги з цього списку має. У Руслана на комп'ютері в текстовому файлі записані всі книги з його домашньої бібліотеки випадково.
#
# Напишіть програму, яка визначає для кожної книги зі списку на прочитання, є вона у Руслана чи ні.
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми в першому рядку подається натуральне число mm — кількість книг у домашній бібліотеці Руслана. У другому рядку записано натуральне число nn – кількість книг у списку на літо. Далі йдуть mm рядків із назвами книг із домашньої бібліотеки та nn рядків назв зі списку на літо.
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести nn рядків, у кожному з яких написано слово YES, якщо книга знайдена в бібліотеці, і NO, якщо ні.

# %%
# put your python code here
n, m = [int(input()) for _ in range(2)]
lst = [input() for _ in range(n)]
for _ in range(m):
    text = input()
    if text in lst: print('YES')
    else: print('NO')
# Out:
# 4
# 4
# Хоббит
# Алиса в стране чудес
# Том Сойер
# Остров сокровищ
# Буратино
# NO
# Хоббит
# YES
# Остров сокровищ
# YES
# Война и мир
# NO

# %% [markdown]
# <h3 align='center'>Дивне захоплення</h3>
# Як відомо, математики дивні люди. Не є винятком і Тимур — автор цього курсу. Щодня Тимур вирішує дві складні математичні завдання. Вирішуючи перше завдання, він записує на першому листку всі числа, які в ньому зустрічаються. Далі він робить паузу та береться за друге завдання. Потім записує на другому листку всі числа, які в ній зустрічаються. Після цього він бере ще один листок і виписує на нього всі збігаються числа з перших двох листочків. Якщо такі числа є, день вийшов, якщо загальних чисел немає, Тимур вважає день невдалим.
#
# Напишіть програму, яка знаходить загальні числа двох листочків або повідомляє, що день не вдався 😏
#
# <b>Формат вхідних даних</b><br>
# На вхід до програми подаються два рядки з числами: у першому рядку числа з першого листочка, у другому з другого.
#
# <b>Формат вихідних даних</b><br>
# Програма повинна вивести числа, що зустрілися на обох листках у відсортованому порядку за спаданням, або словосполучення BAD DAY, якщо таких чисел немає.

# %%
# put your python code here
n = set(input().split(' '))
m = set(input().split(' '))
print('')
if len(n & m) == 0: print('BAD DAY')
else: print(*sorted(n & m, reverse=True, key=int))
# Out:
# 6 56 7 34 14
# 675 45 246 2 1
#
# BAD DAY
